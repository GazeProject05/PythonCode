# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy import stats
import sklearn
ls = np.linspace(0, 60, 1000)

#distribution = mlab.normpdf(ls, 0, 5) + mlab.normpdf(ls, 20, 10)
#distribution = (distribution * 1000).astype(int)
#distribution = distribution/distribution.sum()

#plt.plot(ls, distribution)

import seaborn as sns
sns.set_style("white")
# %matplotlib inline
import pandas as pd
#show the distribution of the data as a histogram
#read our dataset
df = pd.read_excel("reading_all.xlsx")
#show first 5 examples (in BTC)
df.head(n=5)
data = df['PupilLeft']
data = data.str.replace(',','.').astype(float)
#data = df.pupilleft
#plot histogram
sns.distplot(data, bins=100, kde=True)
#try to fit a normal distribution to this data
sns.distplot(data, fit=stats.norm, bins=20, kde=False,)

#sklearn.mixture.GaussianMixture()
Min_graph = min(data)
Max_graph = max(data)
x = np.linspace(Min_graph, Max_graph, 2000)

from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components = 3, tol=0.000001)
gmm.fit(np.expand_dims(data, 1)) # Parameters: array-like, shape (n_samples, n_features), 1 dimension dataset so 1 feature
Gaussian_nr = 1
for mu, sd, p in zip(gmm.means_.flatten(), np.sqrt(gmm.covariances_.flatten()), gmm.weights_):
    print('Gaussian {:}: μ = {:.2}, σ = {:.2}, weight = {:.2}'.format(Gaussian_nr, mu, sd, p))
    g_s = stats.norm(mu, sd).pdf(x) * p
    plt.plot(x, g_s, label='gaussian sklearn');
    Gaussian_nr += 1
sns.distplot(data, bins=20, kde=False, norm_hist=True)
gmm_sum = np.exp([gmm.score_samples(e.reshape(-1, 1)) for e in x]) #gmm gives log probability, hence the exp() function
plt.plot(x, gmm_sum, label='gaussian mixture');
plt.legend();
# Out:
# Gaussian 1: μ = 2.4, σ = 0.11, weight = 0.2
# Gaussian 2: μ = 3.0, σ = 0.22, weight = 0.73
# Gaussian 3: μ = 3.8, σ = 0.16, weight = 0.064

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy import stats
import sklearn
ls = np.linspace(0, 60, 1000)

#distribution = mlab.normpdf(ls, 0, 5) + mlab.normpdf(ls, 20, 10)
#distribution = (distribution * 1000).astype(int)
#distribution = distribution/distribution.sum()

#plt.plot(ls, distribution)

import seaborn as sns
sns.set_style("white")
# %matplotlib inline
import pandas as pd
#show the distribution of the data as a histogram
#read our dataset
df = pd.read_excel("scanning_all.xlsx")
#show first 5 examples (in BTC)
df.head(n=5)
data = df['PupilLeft']
data = data.str.replace(',','.').astype(float)
#data = df.pupilleft
#plot histogram
sns.distplot(data, bins=100, kde=True)
#try to fit a normal distribution to this data
sns.distplot(data, fit=stats.norm, bins=20, kde=False,)

sklearn.mixture.GaussianMixture()
Min_graph = min(data)
Max_graph = max(data)
x = np.linspace(Min_graph, Max_graph, 2000)

from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components = 3, tol=0.000001)
gmm.fit(np.expand_dims(data, 1)) # Parameters: array-like, shape (n_samples, n_features), 1 dimension dataset so 1 feature
Gaussian_nr = 1
for mu, sd, p in zip(gmm.means_.flatten(), np.sqrt(gmm.covariances_.flatten()), gmm.weights_):
    print('Gaussian {:}: μ = {:.2}, σ = {:.2}, weight = {:.2}'.format(Gaussian_nr, mu, sd, p))
    g_s = stats.norm(mu, sd).pdf(x) * p
    plt.plot(x, g_s, label='gaussian sklearn');
    Gaussian_nr += 1
sns.distplot(data, bins=20, kde=False, norm_hist=True)
gmm_sum = np.exp([gmm.score_samples(e.reshape(-1, 1)) for e in x]) #gmm gives log probability, hence the exp() function
plt.plot(x, gmm_sum, label='gaussian mixture');
plt.legend();
# Out:
# Gaussian 1: μ = 2.8, σ = 0.17, weight = 0.61
# Gaussian 2: μ = 3.9, σ = 0.35, weight = 0.13
# Gaussian 3: μ = 2.2, σ = 0.19, weight = 0.26

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy import stats
import sklearn
ls = np.linspace(0, 60, 1000)

#distribution = mlab.normpdf(ls, 0, 5) + mlab.normpdf(ls, 20, 10)
#distribution = (distribution * 1000).astype(int)
#distribution = distribution/distribution.sum()

#plt.plot(ls, distribution)

import seaborn as sns
sns.set_style("white")
# %matplotlib inline
import pandas as pd
#show the distribution of the data as a histogram
#read our dataset
df = pd.read_excel("skimming_all.xlsx")
#show first 5 examples (in BTC)
df.head(n=5)
data = df['PupilLeft']
data = data.str.replace(',','.').astype(float)
#data = df.pupilleft
#plot histogram
sns.distplot(data, bins=100, kde=True)
#try to fit a normal distribution to this data
sns.distplot(data, fit=stats.norm, bins=20, kde=False,)

sklearn.mixture.GaussianMixture()
Min_graph = min(data)
Max_graph = max(data)
x = np.linspace(Min_graph, Max_graph, 2000)

from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components = 3,max_iter=150)
gmm.fit(np.expand_dims(data, 1)) # Parameters: array-like, shape (n_samples, n_features), 1 dimension dataset so 1 feature
Gaussian_nr = 1
for mu, sd, p in zip(gmm.means_.flatten(), np.sqrt(gmm.covariances_.flatten()), gmm.weights_):
    print('Gaussian {:}: μ = {:.2}, σ = {:.2}, weight = {:.2}'.format(Gaussian_nr, mu, sd, p))
    g_s = stats.norm(mu, sd).pdf(x) * p
    plt.plot(x, g_s, label='gaussian sklearn');
    Gaussian_nr += 1
sns.distplot(data, bins=20, kde=False, norm_hist=True)
gmm_sum = np.exp([gmm.score_samples(e.reshape(-1, 1)) for e in x]) #gmm gives log probability, hence the exp() function
plt.plot(x, gmm_sum, label='gaussian mixture');
plt.legend();
# Out:
# Gaussian 1: μ = 2.6, σ = 0.3, weight = 0.22
# Gaussian 2: μ = 3.7, σ = 0.32, weight = 0.24
# Gaussian 3: μ = 3.0, σ = 0.19, weight = 0.55

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy import stats
import sklearn
ls = np.linspace(0, 60, 1000)

#distribution = mlab.normpdf(ls, 0, 5) + mlab.normpdf(ls, 20, 10)
#distribution = (distribution * 1000).astype(int)
#distribution = distribution/distribution.sum()

#plt.plot(ls, distribution)

import seaborn as sns
sns.set_style("white")
# %matplotlib inline
import pandas as pd
#show the distribution of the data as a histogram
#read our dataset
df = pd.read_excel("unknown_all.xlsx")
#show first 5 examples (in BTC)
df.head(n=5)
data = df['PupilLeft']
data = data.str.replace(',','.').astype(float)
#data = df.pupilleft
#plot histogram
sns.distplot(data, bins=100, kde=True)
#try to fit a normal distribution to this data
sns.distplot(data, fit=stats.norm, bins=20, kde=False,)

sklearn.mixture.GaussianMixture()
Min_graph = min(data)
Max_graph = max(data)
x = np.linspace(Min_graph, Max_graph, 2000)

from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components = 1, tol=0.000001)
gmm.fit(np.expand_dims(data, 1)) # Parameters: array-like, shape (n_samples, n_features), 1 dimension dataset so 1 feature
Gaussian_nr = 1
for mu, sd, p in zip(gmm.means_.flatten(), np.sqrt(gmm.covariances_.flatten()), gmm.weights_):
    print('Gaussian {:}: μ = {:.2}, σ = {:.2}, weight = {:.2}'.format(Gaussian_nr, mu, sd, p))
    g_s = stats.norm(mu, sd).pdf(x) * p
    plt.plot(x, g_s, label='gaussian sklearn');
    Gaussian_nr += 1
sns.distplot(data, bins=20, kde=False, norm_hist=True)
gmm_sum = np.exp([gmm.score_samples(e.reshape(-1, 1)) for e in x]) #gmm gives log probability, hence the exp() function
plt.plot(x, gmm_sum, label='gaussian mixture');
plt.legend();
# Out:
# Gaussian 1: μ = 3.0, σ = 0.4, weight = 1.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy import stats
import sklearn
from sklearn.mixture import GaussianMixture
ls = np.linspace(0, 60, 1000)

#distribution = mlab.normpdf(ls, 0, 5) + mlab.normpdf(ls, 20, 10)
#distribution = (distribution * 1000).astype(int)
#distribution = distribution/distribution.sum()

#plt.plot(ls, distribution)

import seaborn as sns
sns.set_style("white")
# %matplotlib inline
import pandas as pd
#show the distribution of the data as a histogram
#read our dataset
df = pd.read_excel("mediaview_all.xlsx")
#show first 5 examples (in BTC)
df.head(n=5)
data = df['PupilLeft']
data = data.str.replace(',','.').astype(float)
#data = df.pupilleft
#plot histogram
sns.distplot(data, bins=100, kde=True)
#try to fit a normal distribution to this data
sns.distplot(data, fit=stats.norm, bins=20, kde=False,)

sklearn.mixture.GaussianMixture()
Min_graph = min(data)
Max_graph = max(data)
x = np.linspace(Min_graph, Max_graph, 2000)


gmm = GaussianMixture(n_components = 2,max_iter=150)
gmm.fit(np.expand_dims(data, 1)) # Parameters: array-like, shape (n_samples, n_features), 1 dimension dataset so 1 feature
Gaussian_nr = 1
for mu, sd, p in zip(gmm.means_.flatten(), np.sqrt(gmm.covariances_.flatten()), gmm.weights_):
    print('Gaussian {:}: μ = {:.2}, σ = {:.2}, weight = {:.2}'.format(Gaussian_nr, mu, sd, p))
    g_s = stats.norm(mu, sd).pdf(x) * p
    plt.plot(x, g_s, label='gaussian sklearn');
    Gaussian_nr += 1
sns.distplot(data, bins=20, kde=False, norm_hist=True)
gmm_sum = np.exp([gmm.score_samples(e.reshape(-1, 1)) for e in x]) #gmm gives log probability, hence the exp() function
plt.plot(x, gmm_sum, label='gaussian mixture');
plt.legend();
# Out:
# Gaussian 1: μ = 2.7, σ = 0.29, weight = 0.75
# Gaussian 2: μ = 3.8, σ = 0.25, weight = 0.25

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy import stats
import sklearn
#ls = np.linspace(0, 60, 1000)
print("Pupil Right Eye")
#distribution = mlab.normpdf(ls, 0, 5) + mlab.normpdf(ls, 20, 10)
#distribution = (distribution * 1000).astype(int)
#distribution = distribution/distribution.sum()

#plt.plot(ls, distribution)

import seaborn as sns
sns.set_style("white")
# %matplotlib inline
import pandas as pd
#show the distribution of the data as a histogram
#read our dataset
df = pd.read_excel("reading_all.xlsx")
#show first 5 examples (in BTC)
df.head(n=5)
data = df['PupilRight']
data = data.str.replace(',','.').astype(float)
#data = df.pupilleft
#plot histogram
sns.distplot(data, bins=100, kde=True)
#try to fit a normal distribution to this data
sns.distplot(data, fit=stats.norm, bins=20, kde=False,)

#sklearn.mixture.GaussianMixture()
Min_graph = min(data)
Max_graph = max(data)
x = np.linspace(Min_graph, Max_graph, 2000)

from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components = 3, tol=0.000001)
gmm.fit(np.expand_dims(data, 1)) # Parameters: array-like, shape (n_samples, n_features), 1 dimension dataset so 1 feature
Gaussian_nr = 1
for mu, sd, p in zip(gmm.means_.flatten(), np.sqrt(gmm.covariances_.flatten()), gmm.weights_):
    print('Gaussian {:}: μ = {:.2}, σ = {:.2}, weight = {:.2}'.format(Gaussian_nr, mu, sd, p))
    g_s = stats.norm(mu, sd).pdf(x) * p
    plt.plot(x, g_s, label='gaussian sklearn');
    Gaussian_nr += 1
sns.distplot(data, bins=20, kde=False, norm_hist=True)
gmm_sum = np.exp([gmm.score_samples(e.reshape(-1, 1)) for e in x]) #gmm gives log probability, hence the exp() function
plt.plot(x, gmm_sum, label='gaussian mixture');
plt.legend();
# Out:
# Pupil Right Eye
# Gaussian 1: μ = 3.0, σ = 0.24, weight = 0.79
# Gaussian 2: μ = 3.9, σ = 0.14, weight = 0.067
# Gaussian 3: μ = 2.2, σ = 0.071, weight = 0.14

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy import stats
import sklearn
#ls = np.linspace(0, 60, 1000)
print("Pupil Right Eye")
#distribution = mlab.normpdf(ls, 0, 5) + mlab.normpdf(ls, 20, 10)
#distribution = (distribution * 1000).astype(int)
#distribution = distribution/distribution.sum()

#plt.plot(ls, distribution)

import seaborn as sns
sns.set_style("white")
# %matplotlib inline
import pandas as pd
#show the distribution of the data as a histogram
#read our dataset
df = pd.read_excel("skimming_all.xlsx")
#show first 5 examples (in BTC)
df.head(n=5)
data = df['PupilRight']
data = data.str.replace(',','.').astype(float)
#data = df.pupilleft
#plot histogram
sns.distplot(data, bins=100, kde=True)
#try to fit a normal distribution to this data
sns.distplot(data, fit=stats.norm, bins=20, kde=False,)

#sklearn.mixture.GaussianMixture()
Min_graph = min(data)
Max_graph = max(data)
x = np.linspace(Min_graph, Max_graph, 2000)

from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components = 3,max_iter=150)
gmm.fit(np.expand_dims(data, 1)) # Parameters: array-like, shape (n_samples, n_features), 1 dimension dataset so 1 feature
Gaussian_nr = 1
for mu, sd, p in zip(gmm.means_.flatten(), np.sqrt(gmm.covariances_.flatten()), gmm.weights_):
    print('Gaussian {:}: μ = {:.2}, σ = {:.2}, weight = {:.2}'.format(Gaussian_nr, mu, sd, p))
    g_s = stats.norm(mu, sd).pdf(x) * p
    plt.plot(x, g_s, label='gaussian sklearn');
    Gaussian_nr += 1
sns.distplot(data, bins=20, kde=False, norm_hist=True)
gmm_sum = np.exp([gmm.score_samples(e.reshape(-1, 1)) for e in x]) #gmm gives log probability, hence the exp() function
plt.plot(x, gmm_sum, label='gaussian mixture');
plt.legend();
# Out:
# Pupil Right Eye
# Gaussian 1: μ = 3.0, σ = 0.2, weight = 0.66
# Gaussian 2: μ = 3.8, σ = 0.38, weight = 0.21
# Gaussian 3: μ = 2.3, σ = 0.17, weight = 0.13

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy import stats
import sklearn
#ls = np.linspace(0, 60, 1000)
print("Pupil Right Eye")
#distribution = mlab.normpdf(ls, 0, 5) + mlab.normpdf(ls, 20, 10)
#distribution = (distribution * 1000).astype(int)
#distribution = distribution/distribution.sum()

#plt.plot(ls, distribution)

import seaborn as sns
sns.set_style("white")
# %matplotlib inline
import pandas as pd
#show the distribution of the data as a histogram
#read our dataset
df = pd.read_excel("scanning_all.xlsx")
#show first 5 examples (in BTC)
df.head(n=5)
data = df['PupilRight']
data = data.str.replace(',','.').astype(float)
#data = df.pupilleft
#plot histogram
sns.distplot(data, bins=100, kde=True)
#try to fit a normal distribution to this data
sns.distplot(data, fit=stats.norm, bins=20, kde=False,)

#sklearn.mixture.GaussianMixture()
Min_graph = min(data)
Max_graph = max(data)
x = np.linspace(Min_graph, Max_graph, 2000)

from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components = 3,max_iter=150)
gmm.fit(np.expand_dims(data, 1)) # Parameters: array-like, shape (n_samples, n_features), 1 dimension dataset so 1 feature
Gaussian_nr = 1
for mu, sd, p in zip(gmm.means_.flatten(), np.sqrt(gmm.covariances_.flatten()), gmm.weights_):
    print('Gaussian {:}: μ = {:.2}, σ = {:.2}, weight = {:.2}'.format(Gaussian_nr, mu, sd, p))
    g_s = stats.norm(mu, sd).pdf(x) * p
    plt.plot(x, g_s, label='gaussian sklearn');
    Gaussian_nr += 1
sns.distplot(data, bins=20, kde=False, norm_hist=True)
gmm_sum = np.exp([gmm.score_samples(e.reshape(-1, 1)) for e in x]) #gmm gives log probability, hence the exp() function
plt.plot(x, gmm_sum, label='gaussian mixture');
plt.legend();
# Out:
# Pupil Right Eye
# Gaussian 1: μ = 2.9, σ = 0.18, weight = 0.63
# Gaussian 2: μ = 4.1, σ = 0.34, weight = 0.12
# Gaussian 3: μ = 2.3, σ = 0.17, weight = 0.25

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy import stats
import sklearn
#ls = np.linspace(0, 60, 1000)
print("Pupil Right Eye")
#distribution = mlab.normpdf(ls, 0, 5) + mlab.normpdf(ls, 20, 10)
#distribution = (distribution * 1000).astype(int)
#distribution = distribution/distribution.sum()

#plt.plot(ls, distribution)

import seaborn as sns
sns.set_style("white")
# %matplotlib inline
import pandas as pd
#show the distribution of the data as a histogram
#read our dataset
df = pd.read_excel("mediaview_all.xlsx")
#show first 5 examples (in BTC)
df.head(n=5)
data = df['PupilRight']
data = data.str.replace(',','.').astype(float)
#data = df.pupilleft
#plot histogram
sns.distplot(data, bins=100, kde=True)
#try to fit a normal distribution to this data
sns.distplot(data, fit=stats.norm, bins=20, kde=False,)

#sklearn.mixture.GaussianMixture()
Min_graph = min(data)
Max_graph = max(data)
x = np.linspace(Min_graph, Max_graph, 2000)

from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components = 4,max_iter=200)
gmm.fit(np.expand_dims(data, 1)) # Parameters: array-like, shape (n_samples, n_features), 1 dimension dataset so 1 feature
Gaussian_nr = 1
for mu, sd, p in zip(gmm.means_.flatten(), np.sqrt(gmm.covariances_.flatten()), gmm.weights_):
    print('Gaussian {:}: μ = {:.2}, σ = {:.2}, weight = {:.2}'.format(Gaussian_nr, mu, sd, p))
    g_s = stats.norm(mu, sd).pdf(x) * p
    plt.plot(x, g_s, label='gaussian sklearn');
    Gaussian_nr += 1
sns.distplot(data, bins=20, kde=False, norm_hist=True)
gmm_sum = np.exp([gmm.score_samples(e.reshape(-1, 1)) for e in x]) #gmm gives log probability, hence the exp() function
plt.plot(x, gmm_sum, label='gaussian mixture');
plt.legend();
# Out:
# Pupil Right Eye
# Gaussian 1: μ = 3.2, σ = 0.069, weight = 0.35
# Gaussian 2: μ = 2.2, σ = 0.14, weight = 0.12
# Gaussian 3: μ = 3.9, σ = 0.16, weight = 0.25
# Gaussian 4: μ = 2.7, σ = 0.063, weight = 0.28

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy import stats
import sklearn
#ls = np.linspace(0, 60, 1000)
print("Pupil Right Eye")
#distribution = mlab.normpdf(ls, 0, 5) + mlab.normpdf(ls, 20, 10)
#distribution = (distribution * 1000).astype(int)
#distribution = distribution/distribution.sum()

#plt.plot(ls, distribution)

import seaborn as sns
sns.set_style("white")
# %matplotlib inline
import pandas as pd
#show the distribution of the data as a histogram
#read our dataset
df = pd.read_excel("unknown_all.xlsx")
#show first 5 examples (in BTC)
df.head(n=5)
data = df['PupilRight']
data = data.str.replace(',','.').astype(float)
#data = df.pupilleft
#plot histogram
sns.distplot(data, bins=100, kde=True)
#try to fit a normal distribution to this data
sns.distplot(data, fit=stats.norm, bins=20, kde=False,)

#sklearn.mixture.GaussianMixture()
Min_graph = min(data)
Max_graph = max(data)
x = np.linspace(Min_graph, Max_graph, 2000)

from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components = 1,max_iter=200)
gmm.fit(np.expand_dims(data, 1)) # Parameters: array-like, shape (n_samples, n_features), 1 dimension dataset so 1 feature
Gaussian_nr = 1
for mu, sd, p in zip(gmm.means_.flatten(), np.sqrt(gmm.covariances_.flatten()), gmm.weights_):
    print('Gaussian {:}: μ = {:.2}, σ = {:.2}, weight = {:.2}'.format(Gaussian_nr, mu, sd, p))
    g_s = stats.norm(mu, sd).pdf(x) * p
    plt.plot(x, g_s, label='gaussian sklearn');
    Gaussian_nr += 1
sns.distplot(data, bins=20, kde=False, norm_hist=True)
gmm_sum = np.exp([gmm.score_samples(e.reshape(-1, 1)) for e in x]) #gmm gives log probability, hence the exp() function
plt.plot(x, gmm_sum, label='gaussian mixture');
plt.legend();
# Out:
# Pupil Right Eye
# Gaussian 1: μ = 3.0, σ = 0.43, weight = 1.0
