# %%
import pandas as pd
import numpy as np

# %%
p1 = pd.read_excel('1Proband1.xlsx')
p2 = pd.read_excel('2Proband2.xlsx')
p3 = pd.read_excel('3Proband3.xlsx')
p5 = pd.read_excel('5Proband5.xlsx')
p6 = pd.read_excel('6Proband6.xlsx')
p7 = pd.read_excel('7Proband7.xlsx')
p8 = pd.read_excel('8Proband8.xlsx')
p9 = pd.read_excel('9Proband9.xlsx')
p10 = pd.read_excel('10Proband10.xlsx')
p11 = pd.read_excel('11Proband11.xlsx')
p12 = pd.read_excel('12Proband12.xlsx')
p13 = pd.read_excel('13Proband13.xlsx')
p14 = pd.read_excel('14Proband14.xlsx')
p15 = pd.read_excel('15Proband15.xlsx')
p16 = pd.read_excel('16Proband16.xlsx')

# %%
result = p1.append([p2,p3,p5,p6,p7,p8,p9,p10,p11,p12,p13,p14,p15,p16])
# Out:
# O:\Installations\Anaconda\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)

# %%
result#set(result['StudioEvent'])
# Out:
#       AbsoluteSaccadicDirection  EyeTrackerTimestamp  FixationIndex  \
# 0                        300,51         1.457365e+15            5.0
# 1                        300,51         1.457365e+15            5.0
# 2                        300,51         1.457365e+15            5.0
# 3                        300,51         1.457365e+15            5.0
# 4                        300,51         1.457365e+15            5.0
# 5                        300,51         1.457365e+15            5.0
# 6                        300,51         1.457365e+15            5.0
# 7                        300,51         1.457365e+15            5.0
# 8                        300,51         1.457365e+15            5.0
# 9                        300,51         1.457365e+15            5.0
# 10                       300,51         1.457365e+15            5.0
# 11                       300,51         1.457365e+15            5.0
# 12                       300,51         1.457365e+15            5.0
# ...

# %%
#read_typesA = set(result['StudioEventIndex'])
#read_typesB = set(result['StudioEventIndex_B'])

# %%
#read_typesA

# %%
#def pupil_per_read(df):

#J = []
#for x in read_typesA:
 #   for y in read_typesB:
        #if x == y and x == :            

maskA = result['StudioEventIndex'] == '2_skimming'
maskb = result['StudioEventIndex_B'] == '2_skimming'

A = result[maskA]
B = result[maskb]

C = A.append([B])

C.drop(columns=['AbsoluteSaccadicDirection', 'EyeTrackerTimestamp', 'FixationIndex',
'FixationPointX (MCSpx)', 'FixationPointY (MCSpx)', 'GazeEventDuration',
'GazeEventType', 'GazeEventTypeDiff', 'GazeEventType_B',
'GazePointIndex', 'GazePointX (MCSpx)', 'GazePointY (MCSpx)',
'KeyPressEventIndex', 'LocalTimeStamp', 'MouseEventIndex',
'MouseEventX (MCSpx)', 'MouseEventY (MCSpx)', 'ParticipantName',
'RecordingDuration', 'RecordingTimestamp',
'RelativeSaccadicDirection', 'SaccadeIndex', 'SaccadicAmplitude',
'StudioEvent', 'StudioEventIndex.1',
'StudioEventIndex_B.1', 'StudioEventTypeDiff',
'StudioEvent_B', 'Unnamed: 11', 'Unnamed: 9', 'ValidityLeft',
'ValidityRight'])



excel_file = pd.ExcelWriter('Proband_One.xlsx')
x.to_excel(excel_file, sheet_name=a, index=False)
excel_file.save()
excel_file.close()

#J.append(C)
 #   n = 0
 #   for x in J:

# %%
#a = str(n)

#n+=1

# %%
# Out:
#       AbsoluteSaccadicDirection  EyeTrackerTimestamp  FixationIndex  \
# 0                        300,51         1.457365e+15            5.0
# 1                        300,51         1.457365e+15            5.0
# 2                        300,51         1.457365e+15            5.0
# 3                        300,51         1.457365e+15            5.0
# 4                        300,51         1.457365e+15            5.0
# 5                        300,51         1.457365e+15            5.0
# 6                        300,51         1.457365e+15            5.0
# 7                        300,51         1.457365e+15            5.0
# 8                        300,51         1.457365e+15            5.0
# 9                        300,51         1.457365e+15            5.0
# 10                       300,51         1.457365e+15            5.0
# 11                       300,51         1.457365e+15            5.0
# 12                       300,51         1.457365e+15            5.0
# ...
